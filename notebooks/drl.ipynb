# %%
# %pip install gymnasium stable-baselines3
# Out:
# Collecting gymnasium
#   Downloading gymnasium-1.2.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.7.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy>=1.21.0 in /home/codespace/.local/lib/python3.12/site-packages (from gymnasium) (2.2.5)
# Collecting cloudpickle>=1.2.0 (from gymnasium)
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from gymnasium) (4.13.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: torch<3.0,>=2.3 in /home/codespace/.local/lib/python3.12/site-packages (from stable-baselines3) (2.7.0+cpu)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (from stable-baselines3) (2.2.3)
# Requirement already satisfied: matplotlib in /home/codespace/.local/lib/python3.12/site-packages (from stable-baselines3) (3.10.1)
# Requirement already satisfied: filelock in /home/codespace/.local/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.13.1)
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (80.3.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/codespace/.local/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.3)
# Requirement already satisfied: networkx in /home/codespace/.local/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /home/codespace/.local/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (2024.6.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->stable-baselines3) (2025.2)
# Downloading gymnasium-1.2.0-py3-none-any.whl (944 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 944.3/944.3 kB 28.1 MB/s eta 0:00:00
# Downloading stable_baselines3-2.7.0-py3-none-any.whl (187 kB)
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, cloudpickle, gymnasium, stable-baselines3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [stable-baselines3]stable-baselines3]
# Successfully installed cloudpickle-3.1.1 farama-notifications-0.0.4 gymnasium-1.2.0 stable-baselines3-2.7.0
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# ============================================
# Section 1: Setup
# ============================================

# Install libraries (only if needed in Kaggle or local Jupyter)
# !pip install gymnasium stable-baselines3 matplotlib

import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import DQN, PPO

# %% [markdown]
# # Deep Reinforcement Learning (DRL) Introduction
# # 딥 강화학습(DRL) 소개
#
# In this lesson, we will:
# 이번 수업에서 우리는:
#
# 1. Learn the basics of Reinforcement Learning (RL) with a simple environment (CartPole).
#    간단한 환경(CartPole)을 이용해 강화학습(RL)의 기본을 학습합니다.
#
# 2. Train a DRL agent using a standard library (`stable-baselines3`).
#    표준 라이브러리(`stable-baselines3`)를 사용하여 DRL 에이전트를 학습시킵니다.
#
# 3. Visualize and interpret the learning process.
#    학습 과정을 시각화하고 해석합니다.
#
# 4. Discuss how these concepts apply to **medical imaging tasks** (e.g., landmark detection, segmentation).
#    이러한 개념이 **의료영상 작업**(예: 랜드마크 탐지, 세분화)에 어떻게 적용되는지 논의합니다.

# %%
# ============================================
# Section 2: Create RL Environment
# ============================================

# CartPole is a classic RL problem:
# The agent must balance a pole on a moving cart.
# 에이전트가 움직이는 카트 위에 막대를 균형 있게 세우는 문제입니다.

env = gym.make("CartPole-v1", render_mode="rgb_array")


# Check action and observation space

print("Observation space:" , env.observation_space)
print("Action space:" , env.action_space)
# Out:
# Observation space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# Action space: Discrete(2)

# %% [markdown]
# ### Key RL Concepts / 주요 RL 개념
#
# - **State (상태)**: The current condition of the environment (pole angle, cart position, etc.).
#   환경의 현재 상태 (막대 각도, 카트 위치 등).
#
# - **Action (행동)**: What the agent can do (move left or right).
#   에이전트가 취할 수 있는 행동 (왼쪽/오른쪽 이동).
#
# - **Reward (보상)**: Feedback given after each action (keeping the pole upright).
#   각 행동 후 주어지는 피드백 (막대를 세워 유지하면 보상).
#
# - **Policy (정책)**: The strategy mapping states → actions.
#   상태를 행동으로 매핑하는 전략.

# %%
# ============================================
# Section 3: Train a DRL Agent (DQN)
# ============================================

# Use Deep Q-Network (DQN) agent
# DQN 에이전트 학습

model = DQN("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=5000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 7441     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 80       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.721    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 2167     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 147      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.635    |
# |    n_updates        | 11       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.601    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2096     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 210      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.549    |
# |    n_updates        | 27       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 16.7     |
# |    exploration_rate | 0.493    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 2021     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 267      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.551    |
# |    n_updates        | 41       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 16.1     |
# |    exploration_rate | 0.39     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1949     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 321      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.539    |
# |    n_updates        | 55       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.308    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1890     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 364      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.496    |
# |    n_updates        | 65       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0
|
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.8      |
# |    ep_rew_mean      | 9.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1453     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4034     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00308  |
# |    n_updates        | 983      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.79     |
# |    ep_rew_mean      | 9.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 1453     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4073     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0041   |
# |    n_updates        | 993      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.76     |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 1453     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4110     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00397  |
# |    n_updates        | 1002     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.74     |
# |    ep_rew_mean      | 9.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 1453     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4149     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00189  |
# |    n_updates        | 1012     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.74     |
# |    ep_rew_mean      | 9.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 1452     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4187     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00138  |
# |    n_updates        | 1021     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.72     |
# |    ep_rew_mean      | 9.72     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1451     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4226     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00361  |
# |    n_updates        | 1031     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.71     |
# |    ep_rew_mean      | 9.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 1449     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4264     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00258  |
# |    n_updates        | 1040     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.73     |
# |    ep_rew_mean      | 9.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 1450     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4306     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00441  |
# |    n_updates        | 1051     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.66     |
# |    ep_rew_mean      | 9.66     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 1449     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4341     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00266  |
# |    n_updates        | 1060     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.71     |
# |    ep_rew_mean      | 9.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 1450     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4380     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00302  |
# |    n_updates        | 1069     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.7      |
# |    ep_rew_mean      | 9.7      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 1451     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4418     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00262  |
# |    n_updates        | 1079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 1452     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4459     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00267  |
# |    n_updates        | 1089     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.7      |
# |    ep_rew_mean      | 9.7      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 1450     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4495     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00295  |
# |    n_updates        | 1098     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.72     |
# |    ep_rew_mean      | 9.72     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 1447     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4535     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0031   |
# |    n_updates        | 1108     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.76     |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 1448     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4576     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00318  |
# |    n_updates        | 1118     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 1449     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4612     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00266  |
# |    n_updates        | 1127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.76     |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 1449     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4651     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00295  |
# |    n_updates        | 1137     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.74     |
# |    ep_rew_mean      | 9.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 1449     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4690     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00289  |
# |    n_updates        | 1147     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.65     |
# |    ep_rew_mean      | 9.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 1449     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4728     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00137  |
# |    n_updates        | 1156     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.64     |
# |    ep_rew_mean      | 9.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 1449     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4765     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00241  |
# |    n_updates        | 1166     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.67     |
# |    ep_rew_mean      | 9.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 1450     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4804     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00195  |
# |    n_updates        | 1175     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.67     |
# |    ep_rew_mean      | 9.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 1450     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4843     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00228  |
# |    n_updates        | 1185     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.64     |
# |    ep_rew_mean      | 9.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 1450     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4880     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00298  |
# |    n_updates        | 1194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.65     |
# |    ep_rew_mean      | 9.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 1451     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4918     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00237  |
# |    n_updates        | 1204     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.58     |
# |    ep_rew_mean      | 9.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 1452     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4955     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0027   |
# |    n_updates        | 1213     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.58     |
# |    ep_rew_mean      | 9.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 1451     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4992     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00153  |
# |    n_updates        | 1222     |
# ----------------------------------

# %%
# ============================================
# Section 4: Evaluate Agent
# ============================================

episodes = 5
for ep in range(episodes):
    obs, _ = env.reset()
    total_reward = 0
    done= False

    while not done:
        action, _ = model.predict(obs, deterministic= True)
        obs, reward, done, truncated, info = env.step(action)
        total_reward += reward

    print(f"Episode {ep+1}: Total reward = {total_reward}")
# Out:
# Episode 1: Total reward = 9.0
# Episode 2: Total reward = 10.0
# Episode 3: Total reward = 10.0
# Episode 4: Total reward = 9.0
# Episode 5: Total reward = 10.0

# %% [markdown]
# ### What we learned here / 여기서 배운 점
#
# - The agent improves its **decision-making** by trial and error.
#   에이전트는 시행착오를 통해 **의사결정 능력**을 향상시킵니다.
#
# - This is very similar to medical imaging tasks where:
#   이는 의료 영상 작업과 매우 유사합니다:
#   - Detecting lesions requires **sequential refinement**.
#     병변 탐지는 **순차적 정밀화**가 필요합니다.
#   - Segmentation can be seen as **step-by-step boundary tracing**.
#     세분화는 **경계선을 단계적으로 추적**하는 것과 같습니다.
#
# ➡ Next: Let’s connect this to a medical dataset example (e.g., Kaggle Chest X-ray).
# ➡ 다음 단계: Kaggle 흉부 X-ray 같은 의료 데이터셋과 연결해 봅시다.
